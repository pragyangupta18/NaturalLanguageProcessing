# %% [markdown]
# # Speech To Text

# %%
# !pip install git+https://github.com/openai/whisper.git
# !sudo apt update && sudo apt install ffmpeg
# Out:
# ...
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-1k38z4i4
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-1k38z4i4
#   Resolved https://github.com/openai/whisper.git to commit ba3f3cd54b0e5b8ce1ab3de13e32122d0d5f98ab
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 14.0 MB/s eta 0:00:00
# ...
#   Created wheel for openai-whisper: filename=openai_whisper-20231117-py3-none-any.whl size=802825 sha256=4431d587559d750086a9a4f7053c6449cefd613dc3f1d5d6d6ea4a0218de5000
#   Stored in directory: /tmp/pip-ephem-wheel-cache-uzafmks1/wheels/8b/6c/d0/622666868c179f156cf595c8b6f06f88bc5d80c4b31dccaa03
# Successfully built openai-whisper
# ...
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-65bd4152-ac62-4aa5-9d01-0aaacba50d18" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-65bd4152-ac62-4aa5-9d01-0aaacba50d18">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !whisper "injuries.mp3" --model medium.en
# Out:
# 100%|█████████████████████████████████████| 1.42G/1.42G [01:36<00:00, 15.8MiB/s]
# [00:00.000 --> 00:12.400]  Runner's knee
# [00:12.400 --> 00:17.080]  Runner's knee is a condition characterized by pain behind or around the kneecap.
# [00:17.080 --> 00:23.400]  It is caused by overuse, muscle imbalance, and inadequate stretching.
# [00:23.400 --> 00:37.720]  Symptoms include pain under or around the kneecap, pain when walking.
# [00:37.720 --> 00:42.720]  The ligaments of the ankle hold the ankle bones and joint in position.
# [00:42.720 --> 00:47.360]  They protect the ankle from abnormal movements such as twisting, turning, and rolling of
# [00:47.360 --> 00:49.000]  the foot.
# [00:49.000 --> 00:55.640]  A sprained ankle happens when the foot twists, rolls, or turns beyond its normal motions.
# [00:55.640 --> 00:59.920]  If the force is too strong, the ligaments can tear.
# ...

# %%
output_file = "injuries.txt"

with open(output_file, "r") as file:
    transcribed_text = file.read()

print("Transcribed text:")
print(transcribed_text)
# Out:
# Transcribed text:
# Runner's knee
# Runner's knee is a condition characterized by pain behind or around the kneecap.
# It is caused by overuse, muscle imbalance, and inadequate stretching.
# Symptoms include pain under or around the kneecap, pain when walking.
# The ligaments of the ankle hold the ankle bones and joint in position.
# They protect the ankle from abnormal movements such as twisting, turning, and rolling of
# the foot.
# A sprained ankle happens when the foot twists, rolls, or turns beyond its normal motions.
# If the force is too strong, the ligaments can tear.
# Symptoms include pain and difficulty moving the ankle, swelling around the ankle, and
# bruising.
# Each of your knees has two menisci C-shaped pieces of cartilage that act like a cushion
# between your shin bone and your thigh bone.
# A meniscus tear happens when you forcibly twist or rotate your knee, especially when
# putting the pressure of your full weight on it, leading to a torn meniscus.
# ...

# %% [markdown]
# # Text to Speech

# %%
import torch
print(torch.__version__)
# Out:
# 2.1.0+cu121

# %%
# !pip install git+https://github.com/suno-ai/bark.git -q
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 kB 3.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 14.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 39.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 10.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 5.6 MB/s eta 0:00:00
# ...

# %%
from bark import SAMPLE_RATE, generate_audio, preload_models
from IPython.display import Audio

preload_models()
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# text_2.pt:   0%|          | 0.00/5.35G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/996k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/625 [00:00<?, ?B/s]
# coarse_2.pt:   0%|          | 0.00/3.93G [00:00<?, ?B/s]
# fine_2.pt:   0%|          | 0.00/3.74G [00:00<?, ?B/s]
# ...

# %% [markdown]
# **Bark Speaker Library**
#
# https://suno-ai.notion.site/8b8e8749ed514b0cbf3f699013548683?v=bc67cff786b04b50b3ceb756fd05f68c

# %%
text_prompt = """
Hello, my name is Pragyan. And, uh - and I like pizza.
But I also have other interests such as playing football.
"""

audio_array = generate_audio(text_prompt)
Audio(audio_array, rate = SAMPLE_RATE)
# Out:
# ...
# 100%|██████████| 27/27 [00:24<00:00,  1.09it/s]
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
